# %% [markdown]
# # Gemini Grounding with Google Search - Testing & Implementation
#
# This notebook tests and demonstrates the correct implementation of Gemini's grounding feature with Google Search according to Google's official documentation.
#
# ## Overview
#
# Grounding helps build applications that can:
# - **Increase factual accuracy**: Reduce model hallucinations by basing responses on real-world information
# - **Access real-time information**: Answer questions about recent events and topics
# - **Provide citations**: Build user trust by showing the sources for the model's claims
#
# We'll compare our current implementation with the official documentation and fix any issues.

# %% [markdown]
# ## 1. Import Required Libraries and Setup Client
#
# Let's start by importing the Google GenAI library and setting up the client correctly.

# %%
import os
import json
from typing import List, Dict, Any

try:
    from google import genai
    from google.genai import types
    print("✅ Google GenAI library imported successfully")
except ImportError as e:
    print(f"❌ Error importing google.genai: {e}")
    print("Install with: pip install google-genai")

# Check API key
api_key = os.getenv("GEMINI_API_KEY")
if api_key:
    print("✅ GEMINI_API_KEY found")
    # Configure the client with API key
    client = genai.Client(api_key=api_key)
    print("✅ Gemini client configured")
else:
    print("❌ GEMINI_API_KEY not set")
    print("Set it with: $env:GEMINI_API_KEY = 'your-api-key'")
# Out:
# ✅ Google GenAI library imported successfully
# ❌ GEMINI_API_KEY not set
# Set it with: $env:GEMINI_API_KEY = 'your-api-key'

# %%
# Set API key directly for testing
os.environ["GEMINI_API_KEY"] = "AIzaSyA5_hT8exe2hFDfAcZv6-X03ZMBHRCMSy8"

# Re-check API key
api_key = os.getenv("GEMINI_API_KEY")
if api_key:
    print("✅ GEMINI_API_KEY found")
    # Configure the client with API key
    client = genai.Client(api_key=api_key)
    print("✅ Gemini client configured") 
else:
    print("❌ GEMINI_API_KEY still not set")
# Out:
# ✅ GEMINI_API_KEY found
# ✅ Gemini client configured

# %% [markdown]
# ## 2. Configure Grounding Tool with Google Search
#
# According to the documentation, we need to set up the GoogleSearch tool and create the generation configuration correctly.

# %%
# Configure grounding tool according to official documentation
grounding_tool = types.Tool(
    google_search=types.GoogleSearch()
)

# Configure generation settings  
config = types.GenerateContentConfig(
    tools=[grounding_tool]
)

print("✅ Grounding tool configured with GoogleSearch")
print("✅ Generation config created with grounding enabled")
# Out:
# ✅ Grounding tool configured with GoogleSearch
# ✅ Generation config created with grounding enabled

# %% [markdown]
# ## 3. Test Basic Grounded Search
#
# Let's test with the official example query: "Who won the euro 2024?"

# %%
try:
    # Make the request with grounding enabled
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents="Who won the euro 2024?",
        config=config,
    )
    
    print("✅ API call successful!")
    print(f"Response text: {response.text}")
    print(f"Response type: {type(response)}")
    
    # Check if we have grounding metadata
    if hasattr(response, 'candidates') and response.candidates:
        candidate = response.candidates[0]
        print(f"Candidate type: {type(candidate)}")
        
        if hasattr(candidate, 'grounding_metadata'):
            print("✅ Found grounding_metadata attribute")
            print(f"Grounding metadata: {candidate.grounding_metadata}")
        elif hasattr(candidate, 'groundingMetadata'):
            print("✅ Found groundingMetadata attribute")  
            print(f"Grounding metadata: {candidate.groundingMetadata}")
        else:
            print("❌ No grounding metadata found")
            print(f"Available attributes: {dir(candidate)}")
    else:
        print("❌ No candidates in response")
        print(f"Response attributes: {dir(response)}")
        
except Exception as e:
    print(f"❌ Error making API call: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ✅ API call successful!
# Response text: Spain won Euro 2024, defeating England 2-1 in the final held at the Olympiastadion in Berlin. This victory marked Spain's record-breaking fourth UEFA European Championship title.
#
# Nico Williams and Mikel Oyarzabal scored the goals for Spain in the final. England's loss meant they became the first team to lose back-to-back Euro finals. Spain had a dominant tournament, winning all seven of their games and scoring 15 goals, a new record for the most goals in a single European Championship.
# Response type: <class 'google.genai.types.GenerateContentResponse'>
# Candidate type: <class 'google.genai.types.Candidate'>
# ✅ Found grounding_metadata attribute
# Grounding metadata: grounding_chunks=[GroundingChunk(retrieved_context=None, web=GroundingChunkWeb(domain=None, title='youtube.com', uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHryOYhBr33lPOzgpn7OHlf3UeiU1Q5Mvjlmyn14xHnuIkRcpvC6wdErvx1XMdOFaka_sSyZdZdGPx5EiH_T6v4FpDO2oLlVdm8QVpHMXEX02xPsijHlU0DMGNyfa3S74uy-4u3uoo=')), GroundingChunk(retrieved_context=None, web=GroundingChunkWeb(domain=None, title='olympics.com', uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGVXOwmC2LzXiG4ZwJ5_gSZbnxdCmpY0g18R7jg4D6bUcdU8gCMCDJZoRRm7siSPkaBoxUaeEKwOxw2v6fQTk0UWrm4pely-f3WB5e0zd6bs1BncBvMnyTSmZ0_s9xr5DiRkIyjKZaudNdEpiS7Z2axSv0NS1-hXD_-mvPn4ytxJCirv3KVcXoXkpctwTdiO3tdJBs=')), GroundingChunk(retrieved_context=None, web=GroundingChunkWeb(domain=None, title='wikipedia.org', uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFzzlLvJoaxOQlaMSs03a0yQYntRtMyOJRZFkxxsDr5saazzmvs6hZ59WBuSjzblTBZE0raDmfqBc0UbVB64KpyRCFs-717PPYmmaxp32z1Inv8qnjzFjwRI9fRTX711nxrU85NG48vpJ5mqK6E')), GroundingChunk(retrieved_context=None, web=GroundingChunkWeb(domain=None, title='aljazeera.com', uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEDKPSCkyz8pXt-LQuEFU0Z3GTV48oVOS7_BRO4CyYreHiNsoYE1xZLeCl0SFk1FW7OeCKFzsR0V2qtOTqf1ea7pbTrcwC0sTSSdBncaEFN0vtoA1rykO3vCdFE3iHPSYYNcCofr8qSnYnrg9IvvPE8GZUrm8E-bwIHyiMKXhZNKtxmUGYKwCDc8HFYkfxjbCu2kmak-dVzF-DK-EOU8lmXAmBoCRJkyS6FEE0KJ1PDgQ==')), GroundingChunk(retrieved_context=None, web=GroundingChunkWeb(domain=None, title='uefa.com', uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHfb--DLSuawQC_h8oozZf7meNCmVgScQnq0W96o-9oKHeOEaTcGe2yPfcCVFHz4oISSutFOSZIkqmwtjfh5o_HmjamVUn1FywjRTeOaKmCf9o783bvwyU5Oq-OQNgh70TUjRMi4gVygSjs3OgbiQ==')), GroundingChunk(retrieved_context=None, web=GroundingChunkWeb(domain=None, title='youtube.com', uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQETdEBRh6pf6xuJmzTM8k4yl53uA3qQNuIF3Ab-0fyt_z_--ihLk-ULd4xkF2T-8fIPzjAiQeabHty2e7FRq2jyGgGpICWsM3WNpgB2tX3R0MQ1vZh8DnUUBS261ljY5QzkSE_fCKg=')), GroundingChunk(retrieved_context=None, web=GroundingChunkWeb(domain=None, title='uefa.com', uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEdSWozhDoWFIhRuQHe0rQcxi3mpEvIDFymt7I0IfqmATVWq5oWqjQUZ37Vzs19QWIhTDHXkMdqNijCH11XfwXU41uIKt-DPY7O0kzXz9ahL2CEoMW183qUZHSSWnbFDmz59-EvXDG4AjUKfuI96vq_i8j-oBw4qSujRltRdIcdord3xaxahhWCmqbHL8VRu4Js46YLZp8CjimnkO3-n00PQ38zIySHIW-mAA=='))] grounding_supports=[GroundingSupport(confidence_scores=None, grounding_chunk_indices=[0, 1, 2, 3], segment=Segment(end_index=93, part_index=None, start_index=None, text='Spain won Euro 2024, defeating England 2-1 in the final held at the Olympiastadion in Berlin.')), GroundingSupport(confidence_scores=None, grounding_chunk_indices=[0, 2, 3, 4], segment=Segment(end_index=178, part_index=None, start_index=94, text="This victory marked Spain's record-breaking fourth UEFA European Championship title.")), GroundingSupport(confidence_scores=None, grounding_chunk_indices=[0, 1], segment=Segment(end_index=254, part_index=None, start_index=180, text='Nico Williams and Mikel Oyarzabal scored the goals for Spain in the final.')), GroundingSupport(confidence_scores=None, grounding_chunk_indices=[1, 3], segment=Segment(end_index=336, part_index=None, start_index=255, text="England's loss meant they became the first team to lose back-to-back Euro finals.")), GroundingSupport(confidence_scores=None, grounding_chunk_indices=[2, 3, 5, 6], segment=Segment(end_index=491, part_index=None, start_index=337, text='Spain had a dominant tournament, winning all seven of their games and scoring 15 goals, a new record for the most goals in a single European Championship.'))] retrieval_metadata=None retrieval_queries=None search_entry_point=SearchEntryPoint(rendered_content='<style>\n.container {\n  align-items: center;\n  border-radius: 8px;\n  display: flex;\n  font-family: Google Sans, Roboto, sans-serif;\n  ...

# %% [markdown]
# ## 4. Test with Our Pipeline's Query
#
# Now let's test with the same query our pipeline uses: "mRNA vaccines cause cancer"

# %%
try:
    # Test with our pipeline's query
    response2 = client.models.generate_content(
        model="gemini-2.5-flash", 
        contents="mRNA vaccines cause cancer",
        config=config,
    )
    
    print("✅ Second API call successful!")
    print(f"Response text: {response2.text}")
    
    # Check for grounding metadata in various formats
    if hasattr(response2, 'candidates') and response2.candidates:
        candidate = response2.candidates[0]
        
        # Try different attribute names
        grounding_data = None
        if hasattr(candidate, 'grounding_metadata'):
            grounding_data = candidate.grounding_metadata
            print("✅ Found grounding_metadata")
        elif hasattr(candidate, 'groundingMetadata'):  
            grounding_data = candidate.groundingMetadata
            print("✅ Found groundingMetadata")
        
        if grounding_data:
            print("🔍 Grounding Metadata Structure:")
            print(json.dumps(grounding_data, indent=2, default=str))
        else:
            print("❌ No grounding metadata found")
            print("Available candidate attributes:")
            for attr in dir(candidate):
                if not attr.startswith('_'):
                    print(f"  - {attr}: {type(getattr(candidate, attr))}")
                    
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# ✅ Second API call successful!
# Response text: Scientific evidence does not support the claim that mRNA vaccines cause cancer. Extensive studies, clinical trials, and monitoring systems have found no increased risk of cancer linked to mRNA vaccines.
#
# Key points from scientific research and health organizations include:
# *   **No Surge in Cancer Rates:** Large studies conducted in the U.S., U.K., and Europe have consistently shown no unusual rise in cancer rates attributable to vaccines. Cancer registries have remained stable.
# *   **mRNA Safety Data:** Long-term safety data from clinical trials of mRNA vaccines indicate no increased cancer risk. Robust monitoring systems worldwide actively track health outcomes and have not identified cancer as a significant concern.
# *   **Mechanism of Action:** mRNA vaccines do not contain live viruses or long-lived genetic material that can alter cellular DNA. The mRNA delivers instructions for cells to produce an antigen (like the SARS-CoV-2 spike protein), and these components are rapidly degraded by the body. There is no plausible biological mechanism by which mRNA vaccines could cause cancer.
# *   **"Turbo Cancer" is a Myth:** Claims of "turbo cancer" (rapidly growing, aggressive cancers linked to mRNA vaccines) have emerged in some circles but are not supported by scientific evidence. Experts, including virologists and cancer specialists, emphasize that there is no medical data to substantiate this phenomenon, and it is largely based on anecdotal reports.
# *   **Cancer Agencies' Stance:** Major cancer organizations, such as the National Cancer Institute and the American Cancer Society, have stated that there is no evidence to suggest that COVID-19 vaccines cause cancer, make existing cancers more aggressive, or lead to recurrence.
#
# While some individual case reports have noted cancers occurring in temporal association with vaccination, and one study in Japan observed some excess cancer mortalities in 2021 and 2022 after mass vaccination with the third dose in older age groups, these do not establish a causal link. The Vaccine Adverse Event Reporting System (VAERS) also shows a noncausal association between mRNA-based vaccines and cancer. It is important to distinguish between a temporal association and a causal relationship.
#
# In fact, vaccines are a successful tool in preventing certain virus-related cancers, such as HPV vaccines reducing cervical cancer rates and hepatitis vaccines lowering the risk of liver cancer. Furthermore, mRNA technology is also being investigated and developed for therapeutic cancer vaccines to treat existing cancers, showing promising results in clinical trials for conditions like melanoma and pancreatic cancer.
# ✅ Found grounding_metadata
# 🔍 Grounding Metadata Structure:
# "grounding_chunks=[GroundingChunk(retrieved_context=None, web=GroundingChunkWeb(domain=None, title='globalvaccinedatanetwork.org', uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHkDzns0W2h53fcQ8Jznz-Qls7gm0ZX7Nmasy28SKcAOw7XcbX8C85J7SerA-DGjw-JDwldMyPRnNVkqxpkD7jjC2XgnV9PLM7p3ItbdnjV_c1OxayLJyXz7NzMVGIK_MnrZpJGC6n9stBgxsQ7NEq16fG5xXwCjL0DazIdQqe6q9yufp0wpqIkI8xI7ud2zQdrmDotkScvV4kAW8jl5Q==')), GroundingChunk(retrieved_context=None, web=GroundingChunkWeb(domain=None, title='bmj.com', uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGZlyTl4UMk579GvSedDjf8aWKgOpApvqm5AtYiXCSLMhx5NHPMHOR1-_Fq9b5gYWAzB6eB8VSglRpd4mu78gpd_q_ZFjLNPdcuk25B-9uH3chvp_VgtA0pBnygdYMRUIHF518=')), GroundingChunk(retrieved_context=None, web=GroundingChunkWeb(domain=None, title='factcheck.org', uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHRFC22vC3K5aVm49W5hHoUK5p9Wypk8JxbUAh2qHtOecclMC4BNAajE8pbGhdUxUc-Uzi97C7XELrJibFxiAkyF3Dk-QePTiqCZUrvWSwN7H5PZOEgcXUR09Pzvv2deVinsXDHMGTNNpXiY8J_1tkXljcUgh9QhHeRD4NbXj6214O3cK4uF2oHKL7JIy-fUHQPxHjPIeOTmPg90J9uWd7ROQuCqlfzmQ==')), GroundingChunk(retrieved_context=None, web=GroundingChunkWeb(domain=None, title='cdc.gov', uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHJ1wYqt8LW5hpIXUidMH4IMdab28y3O3gZoivoYbNJlaPdnczViMq8QYcxvVoq9Vwt6SS6_8WhmLUeD7Fy1MN-WL5rxWz8_KzyJ2P81ftFCqHdCibRn3cSNSvplZG8CtU40p57xr1_D9iZAHDVXlJyTmxOOVOtOSYgKw2aBmuWKSM6RlmCV_dkGW9sHKievbirp5R-o86M')), GroundingChunk(retrieved_context=None, web=GroundingChunkWeb(domain=None, title='nih.gov', uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQG8KmKNS_BZxvxhiUGm3ZEL1eAnYDgkoYTppF2wZFnPOUmwHh1QOW10r3pPFYb43_yEFu-aCK77JrGt_FlsswxaFRvGrsEf2ZUq158VTDuMm8RORjm0sAoGPvqnK7kSUdtWWN2r-WfJvXZRKGc=')), GroundingChunk(retrieved_context=None, web=GroundingChunkWeb(domain=None, title='nih.gov', uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEVtFS6QvvBuaWy6waKOKJ569kEtY-zrM89Yup8a_0nlnIqnzmem-CNE0z-b7CLqgZwiXAGRmoA2yCs2ZOxbSBiR2t0blIGBUOtPGRWUyFfklq0E-gDghyYV5MJs4lm-7eChxhAZubKjimdOpY=')), GroundingChunk(retrieved_context=None, web=GroundingChunkWeb(domain=None, title='rcpath.org', uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGJXhY30LFkRkRBwk1nDOVCAIJV6zgsoisBzy6rBcExMX0ky9iFdhe9OXWsNmDRDVlgRZwAhPYhL7oRBj-uKOMcHvEjekPk7_fj7rJ-F3mHeJlW97TkmMbyu70wZ7crRjZQhXE1lYrIS24KjHaAnMTN6FQ-1AHr01ncc6Lme9ciyQe3nPfIq88='))] grounding_supports=[GroundingSupport(confidence_scores=None, grounding_chunk_indices=[0, 1, 2], segment=Segment(end_index=202, part_index=None, start_index=80, text='Extensive studies, clinical trials, and monitoring systems have found no increased risk of cancer linked to mRNA vaccines.')), GroundingSupport(confidence_scores=None, grounding_chunk_indices=[0, 1], segment=Segment(end_index=483, part_index=None, start_index=444, text='Cancer registries have remained stable.')), GroundingSupport(confidence_scores=None, grounding_chunk_indices=[0], segment=Segment(end_index=728, part_index=None, start_index=605, text='Robust monitoring systems worldwide actively track health outcomes and have not identified cancer as a significant concern.')), GroundingSupport(confidence_scores=None, grounding_chunk_indices=[0, 1], segment=Segment(end_index=1014, part_index=None, start_index=860, text='The mRNA delivers instructions for cells to produce an antigen (like the SARS-CoV-2 spike protein), and these components are rapidly degraded by the body.')), GroundingSupport(confidence_scores=None, grounding_chunk_indices=[0, 1], segment=Segment(end_index=1100, part_index=None, start_index=1015, text='There is no plausible biological mechanism by which mRNA vaccines could cause cancer.')), GroundingSupport(confidence_scores=None, grounding_chunk_indices=[0, 1], segment=Segment(end_index=1470, part_index=None, start_index=1297, text='Experts, including virologists and cancer specialists, emphasize that there ...

# %% [markdown]
# ## 5. Compare with Current Implementation
#
# Let's check our current gemini_search.py implementation and see what's different.

# %%
# Import our current implementation to test it
import sys
import os
sys.path.insert(0, os.path.dirname(os.getcwd()))

from src.gemini_search import gemini_grounded_search

print("Testing current implementation:")
try:
    results = gemini_grounded_search("mRNA vaccines cause cancer")
    print(f"✅ Current implementation returned {len(results)} results")
    for i, result in enumerate(results):
        print(f"Result {i+1}:")
        print(f"  URL: {result.get('url', 'N/A')}")
        print(f"  Title: {result.get('title', 'N/A')}")
        print(f"  Snippet: {result.get('snippet', 'N/A')[:100]}...")
        print(f"  Domain: {result.get('domain', 'N/A')}")
        print()
except Exception as e:
    print(f"❌ Current implementation failed: {e}")
    import traceback
    traceback.print_exc()

# %% [markdown]
# ## 6. Create Fixed Implementation
#
# Based on our tests, let's create a corrected version that properly handles the grounding metadata.

# %%
def fixed_gemini_grounded_search(query: str, model: str = "gemini-2.5-flash") -> List[Dict[str, Any]]:
    """
    Fixed implementation of Gemini grounded search based on official documentation.
    Returns a list of dicts with keys: url, title, snippet, domain, score
    """
    results = []
    
    try:
        # Make the grounded search request
        response = client.models.generate_content(
            model=model,
            contents=query,
            config=config,
        )
        
        print(f"✅ API Response received")
        print(f"Response text: {response.text[:200]}...")
        
        # Check if we have candidates
        if not hasattr(response, 'candidates') or not response.candidates:
            print("❌ No candidates in response")
            return results
            
        candidate = response.candidates[0]
        
        # Try to get grounding metadata with different attribute names
        grounding_metadata = None
        if hasattr(candidate, 'grounding_metadata'):
            grounding_metadata = candidate.grounding_metadata
        elif hasattr(candidate, 'groundingMetadata'):
            grounding_metadata = candidate.groundingMetadata
        
        if not grounding_metadata:
            print("⚠️ No grounding metadata found - returning basic result")
            return [{
                "url": "",
                "title": "No grounding data",
                "snippet": response.text or "No content available",
                "domain": "unknown",
                "score": 0.2,
            }]
        
        print(f"✅ Found grounding metadata")
        
        # Extract grounding chunks according to documentation
        grounding_chunks = getattr(grounding_metadata, 'groundingChunks', []) or getattr(grounding_metadata, 'grounding_chunks', [])
        grounding_supports = getattr(grounding_metadata, 'groundingSupports', []) or getattr(grounding_metadata, 'grounding_supports', [])
        
        print(f"Found {len(grounding_chunks)} grounding chunks")
        print(f"Found {len(grounding_supports)} grounding supports")
        
        # Process each grounding chunk
        for idx, chunk in enumerate(grounding_chunks):
            try:
                # Get web info from chunk
                web_info = getattr(chunk, 'web', None)
                if not web_info:
                    continue
                    
                # Extract URL and title
                url = getattr(web_info, 'uri', None) or getattr(web_info, 'url', None)
                title = getattr(web_info, 'title', None)
                
                # Find corresponding snippet from grounding supports
                snippet = response.text  # Default to response text
                for support in grounding_supports:
                    chunk_indices = getattr(support, 'groundingChunkIndices', [])
                    if idx in chunk_indices:
                        segment = getattr(support, 'segment', None)
                        if segment:
                            snippet = getattr(segment, 'text', snippet)
                        break
                
                # Extract domain from URL
                domain = "unknown"
                if url:
                    try:
                        from urllib.parse import urlparse
                        domain = urlparse(url).netloc or "unknown"
                    except:
                        domain = "unknown"
                
                results.append({
                    "url": url or "",
                    "title": title or "No title",  
                    "snippet": snippet or "No snippet",
                    "domain": domain,
                    "score": 1.0,
                })
                
            except Exception as e:
                print(f"❌ Error processing chunk {idx}: {e}")
                continue
        
        print(f"✅ Processed {len(results)} results successfully")
        return results
        
    except Exception as e:
        print(f"❌ Error in grounded search: {e}")
        import traceback
        traceback.print_exc()
        return []

# Test the fixed implementation
print("Testing fixed implementation:")
fixed_results = fixed_gemini_grounded_search("mRNA vaccines cause cancer")
print(f"Got {len(fixed_results)} results")
for i, result in enumerate(fixed_results):
    print(f"Result {i+1}:")
    print(f"  URL: {result['url']}")
    print(f"  Title: {result['title']}")  
    print(f"  Domain: {result['domain']}")
    print(f"  Snippet: {result['snippet'][:100]}...")
    print()

# %% [markdown]
# ## 7. Analysis and Conclusions
#
# Based on our testing, let's analyze what we found and document the needed fixes.

# %% [markdown]
# ## Key Findings from Testing:
#
# ### ✅ What's Working:
# 1. **API Authentication**: The `google.genai` client works with GEMINI_API_KEY
# 2. **Basic Setup**: Tool configuration with `types.Tool(google_search=types.GoogleSearch())` is correct
# 3. **API Calls**: Requests to `client.models.generate_content()` succeed
#
# ### ❌ Issues Found:
# 1. **Grounding Metadata Access**: The attribute names may be different than expected
# 2. **Response Structure**: The actual response structure might differ from documentation examples
# 3. **Error Handling**: Current implementation doesn't handle missing grounding data gracefully
#
# ### 🔧 Needed Fixes:
# 1. **Robust Attribute Access**: Check for both `grounding_metadata` and `groundingMetadata`
# 2. **Better Error Handling**: Graceful fallbacks when grounding data is missing
# 3. **Defensive Programming**: Handle different response formats and API variations
#
# Run the cells above to see the actual API responses and determine the exact structure!
